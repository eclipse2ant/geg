# %%
# !pip install selenium

# %%
# !pip install webdriver-manager

# %%
# !pip install beautifulsoup4

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd
import os
import datetime

# %%
USER = "test_user"
PASS = "test_pw"

# %%
# GoogleChromeを起動
#browser = webdriver.Chrome() # Mac
browser = webdriver.Chrome(ChromeDriverManager().install())
#browser = driver.get(executable_path = 'chromedriver.exe') # Windows
browser.implicitly_wait(3)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# Driver [C:\Users\tanak\.wdm\drivers\chromedriver\win32\94.0.4606.61\chromedriver.exe] found in cache

# %%
# ログインページするサイトへアクセス
url_login = "https://gisanddata.maps.arcgis.com/apps/opsdashboard/index.html?fbclid=IwAR16Sa3CZJNLblZcUTtTyNWPMDuaFF8k_XY_29PTQ0vMG9P09yXr5NRS9cI#/bda7594740fd40299423467b48e9ecf6"
browser.get(url_login)
time.sleep(3)
print("ログインページ--1 にアクセスしました")
# Out:
# ログインページ--1 にアクセスしました

# %%
browser_class = browser.find_element_by_xpath('//div[@class="widget-body flex-fluid full-width flex-vertical overflow-y-auto overflow-x-hidden"]')

# %%
browser_class.text.split("\n")
#browser_class.text
# Out:
# ['US',
#  '28-Day: 2,754,485 | 48,993',
#  'Totals: 45,130,987 | 728,192',
#  'United Kingdom',
#  '28-Day: 1,036,916 | 3,453',
#  'Totals: 8,581,278 | 139,265',
#  'Turkey',
#  '28-Day: 808,570 | 6,032',
#  'Totals: 7,714,349 | 68,060',
#  'Russia',
#  '28-Day: 714,518 | 24,885',
#  'Totals: 7,936,798 | 221,314',
#  'India',
#  '28-Day: 589,839 | 7,069',
#  'Totals: 34,094,373 | 452,454',
#  'Brazil',
#  '28-Day: 404,243 | 12,510',
#  'Totals: 21,665,912 | 603,855',
#  'Iran',
#  '28-Day: 354,427 | 6,730',
#  'Totals: 5,809,967 | 124,423',
#  'Philippines',
#  '28-Day: 341,670 | 3,827',
#  'Totals: 2,731,735 | 40,972',
#  'Romania',
#  '28-Day: 315,349 | 6,450',
#  'Totals: 1,486,264 | 42,616',
#  'Ukraine',
#  '28-Day: 311,870 | 6,320',
#  'Totals: 2,784,227 | 65,359',
#  'Thailand',
#  '28-Day: 304,626 | 2,867',
#  'Totals: 1,802,934 | 18,407',
#  'Malaysia',
#  '28-Day: 283,946 | 4,249',
#  'Totals: 2,401,866 | 28,062',
#  'Germany',
#  '28-Day: 233,421 | 1,662',
# ...
